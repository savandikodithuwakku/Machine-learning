# %%
import numpy as np
import pandas

# %%
data= pandas.read_csv("kyphosis.csv")
data.head()
# Out:
#   Kyphosis  Age  Number  Start
# 0   absent   71       3      5
# 1   absent  158       3     14
# 2  present  128       4      5
# 3   absent    2       5      1
# 4   absent    1       4     15

# %%
data.shape
# Out:
# (81, 4)

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Kyphosis  81 non-null     str
#  1   Age       81 non-null     int64
#  2   Number    81 non-null     int64
#  3   Start     81 non-null     int64
# dtypes: int64(3), str(1)
# memory usage: 2.7 KB

# %%
x= data.drop("Kyphosis",axis=1) #axis means column
y= data["Kyphosis"]

# %%
x.head()
# Out:
#    Age  Number  Start
# 0   71       3      5
# 1  158       3     14
# 2  128       4      5
# 3    2       5      1
# 4    1       4     15

# %%
y.head()
# Out:
# 0     absent
# 1     absent
# 2    present
# 3     absent
# 4     absent
# Name: Kyphosis, dtype: str

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.3)

# %%
x_train.shape
# Out:
# (56, 3)

# %%
x_test.shape
# Out:
# (25, 3)

# %% [markdown]
# ## Decision Tree Algorithm

# %%
from sklearn.tree import DecisionTreeClassifier
model= DecisionTreeClassifier()
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred = model.predict(x_test)
pred
# Out:
# array(['absent', 'absent', 'absent', 'absent', 'present', 'absent',
#        'absent', 'absent', 'absent', 'absent', 'absent', 'absent',
#        'absent', 'absent', 'absent', 'absent', 'absent', 'present',
#        'absent', 'absent', 'absent', 'absent', 'absent', 'absent',
#        'absent'], dtype=object)

# %%
y_test
# Out:
# 38     absent
# 11     absent
# 3      absent
# 59     absent
# 31     absent
# 48    present
# 70     absent
# 5      absent
# 56     absent
# 75     absent
# 42     absent
# 8      absent
# 41     absent
# 63     absent
# 60    present
# 29     absent
# 26     absent
# 50     absent
# 15     absent
# 32     absent
# 43     absent
# 53     absent
# 68     absent
# 65     absent
# 30     absent
# Name: Kyphosis, dtype: str

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
accuracy_score(y_test,pred) #actual y and predicted y
# Out:
# 0.84

# %%
confusion_matrix(y_test,pred)
# Out:
# array([[21,  2],
#        [ 2,  0]])

# %%
classification_report(y_test,pred)
# Out:
# '              precision    recall  f1-score   support\n\n      absent       0.91      0.91      0.91        23\n     present       0.00      0.00      0.00         2\n\n    accuracy                           0.84        25\n   macro avg       0.46      0.46      0.46        25\nweighted avg       0.84      0.84      0.84        25\n'

# %% [markdown]
# ## Random Forest Algorithm

# %%
from sklearn.ensemble import RandomForestClassifier
model= RandomForestClassifier(n_estimators=50) #number of decision trees
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=50)

# %%
pred= model.predict(x_test)
pred
# Out:
# array(['absent', 'absent', 'absent', 'absent', 'absent', 'absent',
#        'absent', 'absent', 'absent', 'absent', 'present', 'absent',
#        'absent', 'absent', 'absent', 'absent', 'absent', 'present',
#        'absent', 'absent', 'absent', 'absent', 'absent', 'absent',
#        'absent'], dtype=object)

# %%
y_test
# Out:
# 38     absent
# 11     absent
# 3      absent
# 59     absent
# 31     absent
# 48    present
# 70     absent
# 5      absent
# 56     absent
# 75     absent
# 42     absent
# 8      absent
# 41     absent
# 63     absent
# 60    present
# 29     absent
# 26     absent
# 50     absent
# 15     absent
# 32     absent
# 43     absent
# 53     absent
# 68     absent
# 65     absent
# 30     absent
# Name: Kyphosis, dtype: str

# %%
accuracy_score(y_test,pred)
# Out:
# 0.84

# %%
confusion_matrix(y_test,pred)
# Out:
# array([[21,  2],
#        [ 2,  0]])

# %%
data['Kyphosis'].value_counts() #imbalance data need to be balanced for better accuracy 
#present has 25 and absent has 81. So we can see that the data is imbalanced.
#machine hasnt trained well on the present data because it has seen more absent data. So it is predicting more absent than present. 
# We can use oversampling or undersampling to balance the data.
# Out:
# Kyphosis
# absent     64
# present    17
# Name: count, dtype: int64

# %%
import seaborn as sns
sns.pairplot(data, hue="Kyphosis")

# %%
sns.countplot(x='Kyphosis', data=data) #imbalance data
# Out:
# <Axes: xlabel='Kyphosis', ylabel='count'>

# %% [markdown]
# ## Naive Bayes Bayes Algorithm

# %%
from sklearn.naive_bayes import GaussianNB #we use GaussianNB because it is suitable for continuous data 
NB.fit(x_train, y_train)
# Out:
# GaussianNB()

# %%
pred = NB.predict(x_test)
pred
# Out:
# array(['absent', 'absent', 'present', 'absent', 'absent', 'present',
#        'absent', 'absent', 'absent', 'absent', 'present', 'absent',
#        'absent', 'absent', 'present', 'absent', 'absent', 'absent',
#        'absent', 'absent', 'present', 'absent', 'absent', 'absent',
#        'absent'], dtype='<U7')

# %%
y_test
# Out:
# 38     absent
# 11     absent
# 3      absent
# 59     absent
# 31     absent
# 48    present
# 70     absent
# 5      absent
# 56     absent
# 75     absent
# 42     absent
# 8      absent
# 41     absent
# 63     absent
# 60    present
# 29     absent
# 26     absent
# 50     absent
# 15     absent
# 32     absent
# 43     absent
# 53     absent
# 68     absent
# 65     absent
# 30     absent
# Name: Kyphosis, dtype: str

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, pred)
# Out:
# 0.88

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test, pred)
# Out:
# array([[20,  3],
#        [ 0,  2]])
