# %%
# !pip install matplotlib

# %%
# !python -m pip install --upgrade pip

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression #class

# %%
data = pd.read_csv("book1.csv")

# %%
data
# Out:
#    Unnamed: 0  videos  views
# 0           1      30  34000
# 1           2      40  41000
# 2           3      50  42500
# 3           4      60  54300
# 4           5      70  56000

# %%
print(data.shape)
# Out:
# (5, 3)

# %%
print(data['videos']) # pandas series
# Out:
# 0    30
# 1    40
# 2    50
# 3    60
# 4    70
# Name: videos, dtype: int64

# %%
print(data.videos)  # pandas series
# Out:
# 0    30
# 1    40
# 2    50
# 3    60
# 4    70
# Name: videos, dtype: int64

# %%
print(data['videos'].shape)
# Out:
# (5,)

# %%
print(data[['videos']])  # pandas dataframe
# Out:
#    videos
# 0      30
# 1      40
# 2      50
# 3      60
# 4      70

# %%
print(data[['videos']].shape)
# Out:
# (5, 1)

# %%
plt.scatter(data.videos,data.views)
plt.xlabel('No of vdos')
plt.ylabel('Total views')
# Out:
# Text(0, 0.5, 'Total views')

# %%
data.views #pandas series
# Out:
# 0    34000
# 1    41000
# 2    42500
# 3    54300
# 4    56000
# Name: views, dtype: int64

# %%
data.videos
# Out:
# 0    30
# 1    40
# 2    50
# 3    60
# 4    70
# Name: videos, dtype: int64

# %%
x=np.array(data.videos.values) # 1d numpy array

# %%
x
# Out:
# array([30, 40, 50, 60, 70])

# %%
x.shape     #1d
# Out:
# (5,)

# %%
y=np.array(data.views.values) #numpy array

# %%
y
# Out:
# array([34000, 41000, 42500, 54300, 56000])

# %%
model=LinearRegression()       #object from LinearRegression class
#model train x aniwa 2d

#Training the model with a DataFrame
model.fit(data[['videos']], data['views'])  #2d data frame,11d series    = model.fit(data[['videos']], data.views) ✅

#Training with a NumPy array from a Series
#convert data.videos pandas series to 2d numpy array 
#model.fit(np.array(data.videos.values).reshape(-1,1),np.array(data.views.values))    #   2d numpy array,1d numpy array✅ Only NumPy arrays have the .reshape() method so we have to use this method

#model.fit(np.array(data.videos.values).reshape(-1,1), data.views) ✅
#model.fit(np.array(data.videos.values).reshape(-1,1), data['views']) ✅   X NumPy 2D, y pandas Series 1D

# model.fit(data.videos.reshape(-1,1),data.views.values)    this is wrong cauz this outs a pandas we must use .reshape to make x 2d thts essential  That’s why you must convert to .values or np.array() first before reshaping.
# Out:
# LinearRegression()

# %%
new_x= np.array([45]).reshape(-1,1)     #predict using numpy 2d array

# new_x = pd.DataFrame({'videos': [45]})  # predict using pandas dataframe column name must match training

# %%
new_x
# Out:
# array([[45]])

# %%
pred=model.predict(new_x)       #predict using model
pred
# Out:
# C:\Users\Savandi\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([42695.])

# %%
plt.scatter(data.videos,data.views) 
m,c= np.polyfit(x,y,1)
plt.plot(x,m*x+c)

# %%
m
# Out:
# np.float64(572.9999999999999)

# %%
c
# Out:
# np.float64(16910.000000000022)

# %%
y_new=m*45+c     #predict using graph
y_new
# Out:
# np.float64(42695.000000000015)

# %%
model.coef_
# Out:
# array([573.])

# %%
model.intercept_
# Out:
# np.float64(16910.0)
